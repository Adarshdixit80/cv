# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# importing openCV libraries
import cv2

img = cv2.imread('')
type(img)
# Out:
# NoneType

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_742/4260751373.py in <cell line: 0>()
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_742/4226511291.py in <cell line: 0>()
# ----> 1 fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       2 plt.imshow(fix_img)
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
#for gray scale image

img_gray = cv2.imread('00-puppy.jpg',cv2.IMREAD_GRAYSCALE) #fresh read of the image and convert to gray scale
img_gray.shape

# %%
plt.imshow(img_gray)

# %% [markdown]
# So we need to again transform it to look like gray scale using cmap

# %%
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# ##### Resizing Images

# %%
fix_img.shape

# %%
new_img = cv2.resize(fix_img,(1000,400)) #width =1000, height = 400
plt.imshow(new_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_742/1938684356.py in <cell line: 0>()
# ----> 1 new_img = cv2.resize(fix_img,(1000,400)) #width =1000, height = 400
#       2 plt.imshow(new_img)
#
# NameError: name 'fix_img' is not defined

# %%
new_img.shape

# %%
w_ratio = 0.5
h_ratio = 0.5

new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio) #(0,0 location from where you want to resize)
plt.imshow(new_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_742/25245242.py in <cell line: 0>()
#       2 h_ratio = 0.5
#       3
# ----> 4 new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio) #(0,0 location from where you want to resize)
#       5 plt.imshow(new_img)
#
# NameError: name 'fix_img' is not defined

# %%
new_img.shape

# %% [markdown]
# ##### Flip Images

# %%
flip_img = cv2.flip(fix_img,0)
plt.imshow(flip_img) #horizontal

# %%
flip_img1 = cv2.flip(fix_img,1)
plt.imshow(flip_img1) #vertical
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_742/1901569480.py in <cell line: 0>()
# ----> 1 flip_img1 = cv2.flip(fix_img,1)
#       2 plt.imshow(flip_img1) #vertical
#
# NameError: name 'fix_img' is not defined

# %%
flip_img2 = cv2.flip(fix_img,-1)
plt.imshow(flip_img2) #vertical and horizontal both
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_742/2079591346.py in <cell line: 0>()
# ----> 1 flip_img2 = cv2.flip(fix_img,-1)
#       2 plt.imshow(flip_img2) #vertical and horizontal both
#
# NameError: name 'fix_img' is not defined

# %% [markdown]
# ##### Save an image file

# %%
type(fix_img)

# %%
cv2.imwrite('Puppy_fixed_image.jpg',fix_img)

# %% [markdown]
# ##### Resize canvas area

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
cv2.imshow('Puppy',img)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# /tmp/ipykernel_742/2651494775.py in <cell line: 0>()
# ----> 1 cv2.imshow('Puppy',img)
#       2 cv2.waitKey()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      48   def wrapped(*args, **kwargs):
#      49     if not os.environ.get(env_var, False):
# ---> 50       raise DisabledFunctionError(message, name or func.__name__)
#      51     return func(*args, **kwargs)
#      52
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
